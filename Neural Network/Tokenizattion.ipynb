# %%
corpus= """My name is Umar . Hello i am great and what about you. i am a software engineer
"""

print(corpus)
# Out:
# My name is Umar . Hello i am great and what about you. i am a software engineer

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')


nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\umar.alam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\umar.alam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\umar.alam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\umar.alam\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(corpus)
print(sentences)
# Out:
# ['My name is Umar .', 'Hello i am great and what about you.', 'i am a software engineer']

# %%
# Tokenization
# Paragraph --> words
# Sentence --> words

from nltk.tokenize import word_tokenize

word_tokenize(corpus)
# Out:
# ['My',
#  'name',
#  'is',
#  'Umar',
#  '.',
#  'Hello',
#  'i',
#  'am',
#  'great',
#  'and',
#  'what',
#  'about',
#  'you',
#  '.',
#  'i',
#  'am',
#  'a',
#  'software',
#  'engineer']

# %%
# Comments of product is a positive review or negative review
# Reviews ----> eating, eat, eaten [going, gone, goes] ---> go

words = [
    "eating", "eats", "eaten",
    "writing", "writes",
    "programming", "programs"
]

# %%
from nltk.stem import PorterStemmer

stemming = PorterStemmer()

for word in words:
    print(word + " ----> " + stemming.stem(word))
# Out:
# eating ----> eat
# eats ----> eat
# eaten ----> eaten
# writing ----> write
# writes ----> write
# programming ----> program
# programs ----> program

# %%
stemming.stem("ssitting")
# Out:
# 'ssit'

# %%
from nltk.stem import SnowballStemmer

words = ["eating", "eats", "eaten", "writing", "writes", "programming", "programs"]

snowball_stemmer = SnowballStemmer("english")

for word in words:
    print(f"{word} ----> {snowball_stemmer.stem(word)}")
# Out:
# eating ----> eat
# eats ----> eat
# eaten ----> eaten
# writing ----> write
# writes ----> write
# programming ----> program
# programs ----> program

# %%
stemming.stem("fairly"), stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
# this one is efficent
snowball_stemmer.stem("fairly"), snowball_stemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
# POS tags:
# Noun -> n
# Verb -> v
# Adjective -> a
# Adverb -> r

print(lemmatizer.lemmatize("going", pos='v'))

words = [
    "eating", "eats", "eaten",
    "writing", "writes",
    "programming", "programs"
]

for word in words:
    print(word, "---->", lemmatizer.lemmatize(word, pos='v'))
# Out:
# go
# eating ----> eat
# eats ----> eat
# eaten ----> eat
# writing ----> write
# writes ----> write
# programming ----> program
# programs ----> program

# %%
from nltk.stem import PorterStemmer

from nltk.corpus import stopwords

import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\umar.alam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
paragraph = """ History is the study of past events and the development of human civilizations over time. It helps us understand how societies, cultures, and governments evolved through different periods. Ancient civilizations such as Egypt, Mesopotamia, Greece, and Rome made significant contributions to art, science, architecture, and politics. Historians examine written records, artifacts, and other sources to learn about the lives of people who lived in the past. By studying history, we can gain valuable lessons from previous successes and mistakes, allowing us to make better decisions for the future."""

# %%
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

print(stop_words)
# Out:
# {'does', 'below', 'they', 'don', 'he', 'that', 'do', 'when', "they'll", 'had', 'each', 'were', 'other', "isn't", 'be', 'ours', 'wouldn', "didn't", 'above', 'will', 'against', 'only', 'during', "he'd", 'our', 'than', 'your', "don't", 'from', 'their', 'doesn', 've', 's', 'to', "they'd", 'into', 'if', 'no', 'aren', 'is', 'same', 'we', "weren't", "it'll", "doesn't", 'i', 'a', 'themselves', 'been', 'mustn', 'by', "hasn't", "i'm", 'where', 'once', "wasn't", "she's", 'having', 'because', 'can', 'didn', "he'll", 'shan', 'couldn', 'through', 'needn', 'over', 'few', 'again', 'off', 'won', 'up', 'between', 'this', 'ain', 'my', "won't", 'should', "should've", 'hadn', 'it', "mightn't", 'about', 'has', 'an', 'm', "he's", 'now', 'myself', 'or', 'the', "wouldn't", 'too', 'its', 'while', "aren't", "couldn't", 'down', "hadn't", 'being', 'under', 'of', 'such', 'for', 'any', 'own', 'she', 'whom', 'so', 'are', 'his', 'itself', 'in', 'shouldn', 'himself', 'what', "you'd", 'some', "you'll", "i've", "you're
# ...

# %%
sentences=nltk.sent_tokenize(paragraph)

# %%
type(sentences)
# Out:
# list

# %%
# Apply Stopwords And Filter And then Apply Stemming

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])

    words = [snowball_stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    # converting all the words to sentences
    sentences[i]= ' '.join(words)

# %%
print(words)
# Out:
# ['by', 'studi', 'histori', ',', 'gain', 'valuabl', 'lesson', 'previous', 'success', 'mistak', ',', 'allow', 'us', 'make', 'better', 'decis', 'futur', '.']

# %%
print(sentences)
# Out:
# ['histori studi past event develop human civil time .', 'it help us understand societi , cultur , govern evolv differ period .', 'ancient civil egypt , mesopotamia , greec , rome made signific contribut art , scienc , architectur , polit .', 'historian examin written record , artifact , sourc learn live peopl live past .', 'by studi histori , gain valuabl lesson previous success mistak , allow us make better decis futur .']

# %%
# now check with WordNetLemmitization

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])

    words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    # converting all the words to sentences
    sentences[i]= ' '.join(words)

# %%
print(words)
# Out:
# ['studi', 'histori', ',', 'gain', 'valuabl', 'lesson', 'previous', 'success', 'mistak', ',', 'allow', 'u', 'make', 'better', 'decis', 'futur', '.']

# %%
print(sentences)
# Out:
# ['histori studi past event develop human civil time .', 'help u understand societi , cultur , govern evolv differ period .', 'ancient civil egypt , mesopotamia , greec , rome made signific contribut art , scienc , architectur , polit .', 'historian examin written record , artifact , sourc learn live peopl live past .', 'studi histori , gain valuabl lesson previous success mistak , allow u make better decis futur .']

# %%
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\umar.alam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\umar.alam\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# look at the part of speech of each word

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])

    words = [word for word in words if word not in set(stopwords.words('english'))]
    # converting all the words to sentences
    # sentences[i]= ' '.join(words)
    post_tags = nltk.pos_tag(words)
    print(post_tags)
# Out:
# [('histori', 'NN'), ('studi', 'NN'), ('past', 'IN'), ('event', 'NN'), ('develop', 'NN'), ('human', 'JJ'), ('civil', 'JJ'), ('time', 'NN'), ('.', '.')]
# [('help', 'NN'), ('u', 'VB'), ('understand', 'JJ'), ('societi', 'NN'), (',', ','), ('cultur', 'NN'), (',', ','), ('govern', 'JJ'), ('evolv', 'NN'), ('differ', 'NN'), ('period', 'NN'), ('.', '.')]
# [('ancient', 'JJ'), ('civil', 'JJ'), ('egypt', 'NN'), (',', ','), ('mesopotamia', 'NN'), (',', ','), ('greec', 'NN'), (',', ','), ('rome', 'NN'), ('made', 'VBD'), ('signific', 'JJ'), ('contribut', 'JJ'), ('art', 'NN'), (',', ','), ('scienc', 'NN'), (',', ','), ('architectur', 'NN'), (',', ','), ('polit', 'NN'), ('.', '.')]
# [('historian', 'JJ'), ('examin', 'NN'), ('written', 'VBN'), ('record', 'NN'), (',', ','), ('artifact', 'NN'), (',', ','), ('sourc', 'NN'), ('learn', 'RBR'), ('live', 'JJ'), ('peopl', 'NN'), ('live', 'JJ'), ('past', 'NN'), ('.', '.')]
# ...
